# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import igraph
import itertools
import random
import math
from ast import literal_eval
from joblib import Parallel, delayed
import joblib
import scipy
import os
from os.path import isfile, join
from scipy.optimize import curve_fit

def func(x, a, b, c, alpha):
    return a * (x** alpha) + b * (x ** (alpha - 1)) + c

# %%
os.chdir('/nv/hp16/yma412/data')    
mypath = '/nv/hp16/yma412/data'
file_list = [f for f in os.listdir(mypath) if isfile(join(mypath, f))]
 
var_list = ['Boundary_size','Total_hole_size','avg_hole_boundary_distance','time','max_hole_size']
x_var_list = var_list.copy()
x_var_list.remove('time')

# %%
time_list_used = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300]
total_hole = [13.167927639470014, 21.369491481225428, 27.525335294653235, 32.78366055521255, 36.86766333251403, 40.761596285372974, 43.833205151732564, 48.61447380218224, 49.55971869085535, 53.224523952309326, 57.81106585538218, 59.57374982043406, 60.95176871190129, 67.31142080933496, 66.05942663880643, 67.6067266289789, 73.90851655810594, 74.68976727997173, 76.72291382309137, 76.11906562190022, 80.81515878156084, 81.32545846285893, 85.00378741488448, 84.0288177842472, 87.98248983472517, 90.99063674343078]

# %%
plt.plot(time_list_used, total_hole, 'b-')

# %%
def fit_model(x,y):
    popt, pcov = curve_fit(func, x, y, maxfev=5000)
    plt.plot(x, func(x, *popt), 'r-')
    plt.plot(x, y, 'b-')
    print (popt)

# %%
fit_model(time_list_used, Total_hole_size_data)
# Out:
# [ 1.68393467e+00 -5.29782052e+05  5.29802932e+05  1.00003065e+00]

# %%
Boundary_size_list_data
# Out:
# [401.3380281690141,
#  963.6150234741784,
#  1548.8967136150234,
#  2145.370892018779,
#  2751.450704225352,
#  3358.9483568075116,
#  3963.0985915492956,
#  4590.0,
#  5202.028169014085,
#  5802.366197183099,
#  6420.206572769953,
#  7051.638497652582,
#  7664.431924882629,
#  8285.079812206573,
#  8892.464788732394,
#  9526.666666666666,
#  10135.962441314554,
#  10776.591549295774,
#  11395.464788732394,
#  12010.713615023475,
#  12646.413145539906,
#  13274.633802816901,
#  13899.582159624413,
#  14533.920187793427,
#  15143.098591549297,
#  15768.107981220657]
